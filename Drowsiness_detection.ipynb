# %%
import cv2
import os
from keras.models import load_model
import numpy as np
from pygame import mixer
import datetime 

mixer.init()
sound = mixer.Sound('alarm.wav')

face = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')



lbl=['Closed','Open']

model = load_model('models/cnnCat2.h5')
path = os.getcwd()
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
count=0
Time=0
thicc=2
rpred=[99]
lpred=[99]

while(True):
    ret, frame = cap.read()
    height,width = frame.shape[:2] 

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
    left_eye = leye.detectMultiScale(gray)
    right_eye =  reye.detectMultiScale(gray)

    cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )

    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y) , (x+w,y+h) , (100,100,100) , 1 )

    for (x,y,w,h) in right_eye:
        r_eye=frame[y:y+h,x:x+w]
        count=count+1
        r_eye = cv2.cvtColor(r_eye,cv2.COLOR_BGR2GRAY)
        r_eye = cv2.resize(r_eye,(24,24))
        r_eye= r_eye/255
        r_eye=  r_eye.reshape(24,24,-1)
        r_eye = np.expand_dims(r_eye,axis=0)
        #rpred = model.predict_classes(r_eye)
        predict_x = model.predict(r_eye)
        print(predict_x)
        rpred = np.argmax(predict_x,axis=1)
        print(rpred)
        #print(rpred)
        if(rpred[0]==1):
            lbl='Open' 
        if(rpred[0]==0):
            lbl='Closed'
        break

    for (x,y,w,h) in left_eye:
        l_eye=frame[y:y+h,x:x+w]
        count=count+1
        l_eye = cv2.cvtColor(l_eye,cv2.COLOR_BGR2GRAY)  
        l_eye = cv2.resize(l_eye,(24,24))
        l_eye= l_eye/255
        l_eye=l_eye.reshape(24,24,-1)
        l_eye = np.expand_dims(l_eye,axis=0)
        #lpred = model.predict_classes(l_eye)
        predict_x = model.predict(l_eye)
        lpred = np.argmax(predict_x,axis=1)
        if(lpred[0]==1):
            lbl='Open'   
        if(lpred[0]==0):
            lbl='Closed'
        break
        
    dt = str(datetime.datetime.now()) 
    cv2.putText(frame,dt,(290,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)     

    if(rpred[0]==0 and lpred[0]==0):
        Time=Time+1
        cv2.putText(frame,"Closed",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    # if(rpred[0]==1 or lpred[0]==1):
    else:
        Time=Time-1
        cv2.putText(frame,"Open",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
        
    dt = str(datetime.datetime.now()) 
    cv2.putText(frame,dt,(1200,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)    
    if(Time<0):
        Time=0   
    cv2.putText(frame,'Time:'+str(Time),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(Time>5):
        #person is feeling sleepy so we beep the alarm
        cv2.imwrite(os.path.join(path,'image.jpg'),frame)
        try:
            sound.play()
            
        except:  # isplaying = False
            pass
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc)
    if(Time>10):
        cv2.putText(frame,"MESSAGE SENT",(200,height-400),font,1,(0,255,0),1,cv2.LINE_AA)
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc)
        
    cv2.imshow('Drowsey Detection',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Himaja\anaconda3\nandu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\Himaja\anaconda3\nandu\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:tensorflow:From C:\Users\Himaja\anaconda3\nandu\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
import cv2 as cv
img=cv.imread()
cv.imshow(nandu,img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29316/3614386304.py in <module>
#       1 import cv2 as cv
# ----> 2 img=cv.imread()
#       3 cv.imshow(nandu,img)
#
# TypeError: imread() missing required argument 'filename' (pos 1)

# %%
import tensorflow as ts
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28884/3285259101.py in <module>
# ----> 1 import tensorflow as ts
#
# ~\anaconda3\nandu\lib\site-packages\tensorflow\__init__.py in <module>
#      46 _tf2.enable()
#      47
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# ~\anaconda3\nandu\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ...

# %%
pip install tensorflow
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Himaja\\anaconda3\\nandu\\Lib\\site-packages\\~1mpy\\.libs\\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.

# %%
import numpy as np

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
np.__version__
# Out:
# '1.23.0'

# %%
print('hii')
# Out:
# hii

# %%
pip install numpy==1.23.0
# Out:
# ...
#   Using cached numpy-1.23.0-cp39-cp39-win_amd64.whl (14.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\himaja\anaconda3\nandu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\himaja\anaconda3\nandu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\himaja\anaconda3\nandu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\himaja\anaconda3\nandu\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# tensorflow-intel 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.0 which is incompatible.
# ...

# %%
print('hii')
# Out:
# hii

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#[20:03, 3/9/2024] Akhila @ ECE @ G7: import cv2
import os
from keras.models import load_model
import numpy as np
from pygame import mixer
import time

from twilio.rest import Client
from geopy.geocoders import Nominatim

# Twilio Configuration
account_sid = 'ACc8e5a16fb96a16db0c32f22ce3db8ad1'
auth_token = '0789b6ef246f08f18822b088dfeee19e'
client = Client(account_sid, auth_token)
from_number = '+18145243614'
to_number = '+919513012552'                                                                                     

mixer.init()
sound = mixer.Sound('alarm.wav')

face = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')



lbl=['Close','Open']

model = load_model('models/cnnCat2.h5')
path = os.getcwd()
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
count=0
score=0
thicc=2
rpred=[99]
lpred=[99]

geolocator = Nominatim(user_agent="Drowsiness Detection")  # Initialize geopy geolocator

def send_sms(body):
    message = client.messages.create(
        body=body,
        from_=from_number,
        to=to_number
    )
    print("SMS Sent")

def get_location():
    # Get the live location
    lat = 0.0  # Replace with actual latitude
    lon = 0.0  # Replace with actual longitude
    location = geolocator.reverse(f"{lat}, {lon}")
    return location

start_alarm_time = None
start_sms_time = None
sms_counter = 0  # Counter to limit the number of SMS messages

# Variable to track the previous score
prev_score = 0


while(True):
    ret, frame = cap.read()
    height,width = frame.shape[:2] 

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
    left_eye = leye.detectMultiScale(gray)
    right_eye =  reye.detectMultiScale(gray)

    cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )

    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y) , (x+w,y+h) , (100,100,100) , 1 )

    for (x,y,w,h) in right_eye:
        r_eye=frame[y:y+h,x:x+w]
        count=count+1
        r_eye = cv2.cvtColor(r_eye,cv2.COLOR_BGR2GRAY)
        r_eye = cv2.resize(r_eye,(24,24))
        r_eye= r_eye/255
        r_eye=  r_eye.reshape(24,24,-1)
        r_eye = np.expand_dims(r_eye,axis=0)
        #rpred = model.predict_classes(r_eye)
        predict_x = model.predict(r_eye)
        print(predict_x)
        rpred = np.argmax(predict_x,axis=1)
        print(rpred)
        #print(rpred)
        if(rpred[0]==1):
            lbl='Open' 
        if(rpred[0]==0):
            lbl='Closed'
        break

    for (x,y,w,h) in left_eye:
        l_eye=frame[y:y+h,x:x+w]
        count=count+1
        l_eye = cv2.cvtColor(l_eye,cv2.COLOR_BGR2GRAY)  
        l_eye = cv2.resize(l_eye,(24,24))
        l_eye= l_eye/255
        l_eye=l_eye.reshape(24,24,-1)
        l_eye = np.expand_dims(l_eye,axis=0)
        #lpred = model.predict_classes(l_eye)
        predict_x = model.predict(l_eye)
        lpred = np.argmax(predict_x,axis=1)
        if(lpred[0]==1):
            lbl='Open'   
        if(lpred[0]==0):
            lbl='Closed'
        break

    if(rpred[0]==0 and lpred[0]==0):
        score=score+1
        cv2.putText(frame,"Closed",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    # if(rpred[0]==1 or lpred[0]==1):
    else:
        score=score-1
        cv2.putText(frame,"Open",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    
        
    if(score<0):
        score=0   
    cv2.putText(frame,'Score:'+str(score),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(score>5):
        #person is feeling sleepy so we beep the alarm
        cv2.imwrite(os.path.join(path,'image.jpg'),frame)
        try:
            sound.play()
            
        except:  # isplaying = False
            pass
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc) 
    if prev_score <= 20 and score > 20 and sms_counter < 3:
        try:
            location = get_location()  # Fetch live location
            send_sms(f'The driver seems drowsy. Please check. Location: {location}')  # Send SMS with live location
            start_sms_time = time.time()
            sms_counter += 1
            print('message')
        except Exception as e:
            print("Error:", e)
    
    # Check for score transitions (decreased to below 10 and then increased to 20 again)
    if prev_score > 10 and score <= 10 and sms_counter < 3:
        sms_counter = 0  # Reset SMS counter
        start_sms_time = None  # Reset SMS timer
    
    # Update previous score
    prev_score = score
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 140ms/step
# [[4.0642291e-04 9.9959356e-01]]
# [1]
# ...
# 1/1 [==============================] - 0s 41ms/step
# [[0.00120981 0.9987902 ]]
# [1]
# ...
# 1/1 [==============================] - 0s 48ms/step
# [[0.00118062 0.9988193 ]]
# [1]
# 1/1 [==============================] - 0s 42ms/step
# [[0.00376699 0.99623305]]
# [1]
# ...
# 1/1 [==============================] - 0s 40ms/step
# [[0.0036176  0.99638236]]
# [1]
# ...
# 1/1 [==============================] - 0s 39ms/step
# [[0.00908451 0.9909155 ]]
# [1]
# ...
# 1/1 [==============================] - 0s 40ms/step
# [[0.0186838 0.9813162]]
# [1]
# ...
# 1/1 [==============================] - 0s 38ms/step
# [[0.01564396 0.984356  ]]
# [1]
# ...
# 1/1 [==============================] - 0s 42ms/step
# [[9.990170e-01 9.829416e-04]]
# [0]
# 1/1 [==============================] - 0s 40ms/step
# [[0.9913483  0.00865171]]
# [0]
# 1/1 [==============================] - 0s 48ms/step
# [[9.992889e-01 7.110613e-04]]
# [0]
# ...

# %%
pip install geopy
# Out:
# ...
#
# ...
